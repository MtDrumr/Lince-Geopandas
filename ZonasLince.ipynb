# %%
import pandas as pd
import numpy as np
import os
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import geopandas
import folium
from folium import plugins
import requests
import geopandas as gpd
from shapely.geometry import Polygon

# %%
list1=[
(-12.0882483,-77.0481562),
(-12.0852381,-77.0487195),
(-12.0830168,-77.0461519),
(-12.0831728,-77.0437315),
(-12.0829066,-77.0419760),
(-12.0806133,-77.0418493),
(-12.0798735,-77.0363455),
(-12.0795248,-77.0340598),
(-12.0787554,-77.0283873),
(-12.0855543,-77.0256259),
(-12.0907578,-77.0236173),
(-12.0873794,-77.0385976),
(-12.0877719,-77.0411130),
(-12.0879446,-77.0425158),
(-12.0844757,-77.0415891),
(-12.0845098,-77.0418392),
(-12.0856323,-77.0414714),
(-12.0848357,-77.0355830),
(-12.0845169,-77.0333614),
(-12.0858572,-77.0354572),
(-12.0855445,-77.0332062),
(-12.0837365,-77.0280918),
(-12.0859330,-77.0284258),
(-12.0918362,-77.0301183),
(-12.0911476,-77.0299399),
(-12.0908824,-77.0324193),
(-12.0906723,-77.0336545),
(-12.0887150,-77.0350658),
(-12.0885767,-77.0340092),
(-12.0893074,-77.0349726),
(-12.0897287,-77.0382360),
(-12.0904565,-77.0432078),
(-12.0912263,-77.0431237),
(-12.0916951,-77.0464979),
(-12.0913771,-77.0465549),
(-12.0915729,-77.0476520),
(-12.0877315,-77.0445311),
(-12.0891458,-77.0339136)
]

list2=[]

mapa1=folium.Map(location = [-12.085,-77.04], tiles='OpenStreetMap', zoom_start = 15)

for x in range(len(list1)):
    npunto="P{}".format(x+1)
    list2.append(npunto)
    mapa1.add_child(folium.Marker(location = list1[x],popup = npunto))
    
data=pd.DataFrame(data={"npunto":list2,"punto":list1})

mapa1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a156d1790c59469b1775efc5efc5a853 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a156d1790c59469b1775efc5efc5a853&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a156d1790c59469b1775efc5efc5a853 = L.map(
#                 &quot;map_a156d1790c59469b1775efc5efc5a853&quot;,
#                 {
#                     center: [-12.085, -77.04],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4279b36a9ad59dc754287cb01b583792 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a156d1790c59469b1775efc5efc5a853);
#
#
#             var marker_23da8bb8afa5e73f502cb3ead097bd36 = L.marker(
#                 [-12.0882483, -77.0481562],
#                 {}
#             ).addTo(map_a156d1790c59469b1775efc5efc5a853);
#
#
#         var popup_1c81234f09ac952291a58c91162cb8c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_683aed05832b15076d037a9133ccf75b = $(`&lt;div id=&quot;html_683aed05832b15076d037a9133ccf75b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P1&lt;/div&gt;`)[0];
#             popup_1c81234f09ac952291a58c91162cb8c2.setContent(html_683aed05832b15076d037a9133ccf75b);
#
#
#         marker_23da8bb8afa5e73f502cb3ead097bd36.bindPopup(popup_1c81234f09ac952291a58c91162cb8c2)
#         ;
#
#
#
#
#             var marker_0e732d20410a704d85452bd120d0a843 = L.marker(
#                 [-12.0852381, -77.0487195],
#                 {}
#             ).addTo(map_a156d1790c59469b1775efc5efc5a853);
#
#
#         var popup_7c95701f7570f504ad5aa3ef77894a50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f0e45651458627ccc977d5b17915b47e = $(`&lt;div id=&quot;html_f0e45651458627ccc977d5b17915b47e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P2&lt;/div&gt;`)[0];
#             popup_7c95701f7570f504ad5aa3ef77894a50.setContent(html_f0e45651458627ccc977d5b17915b47e);
#
#
#         marker_0e732d20410a704d85452bd120d0a843.bindPopup(popup_7c95701f7570f504ad5aa3ef77894a50)
#         ;
#
#
#
#
#             var marker_9409a381f8b67d2bc4181a5cec5b4f53 = L.marker(
#                 [-12.0830168, -77.0461519],
#                 {}
#             ).addTo(map_a156d1790c59469b1775efc5efc5a853);
#
#
#         var popup_3bee327bf0462230564c5b9dc09692f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d021e3b82dee98a62222289f1c8ec389 = $(`&lt;div id=&quot;html_d021e3b82dee98a62222289f1c8ec389&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P3&lt;/div&gt;`)[0];
#             popup_3bee327bf0462230564c5b9dc09692f3.setContent(html_d021e3b82dee98a62222289f1c8ec389);
#
#
#         marker_9409a381f8b67d2bc4181a5cec5b4f53.bindPopup(popup_3bee327bf0462230564c5b9dc09692f3)
#         ;
#
#
#
#
#             var marker_b10cc2d2fd44d3db5255ce72eaa0684f = L.marker(
#                 [-12.0831728, -77.0437315],
#                 {}
#             ).addTo(map_a156d1790c59469b1775efc5efc5a853);
#
#
#         var popup_9b62d9022673498dcdab6443b3989ce6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b56e76df9ad5ccaabd680b1d3f2c87e7 = $(`&lt;div id=&quot;html_b56e76df9ad5ccaabd680b1d3f2c87e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P4&lt;/div&gt;`)[0];
#             popup_9b62d9022673498dcdab6443b3989ce6.setContent(html_b56e76df9ad5ccaabd680b1d3f2c87e7);
#
#
#         marker_b10cc2d2fd44d3db5255ce72eaa0684f.bindPopup(popup_9b62d9022673498dcdab6443b3989ce6)
#         ;
#
#
#
#
#             var marker_cfa7fd45e9cf63cc572ecbe54c5abfbc = L.marker(
#                 [-12.0829066, -77.041976],
#                 {}
#             ).addTo(map_a156d1790c59469b1775efc5efc5a853);
#
#
#         var popup_9c547da0630076b55ed8e7a8b0abcb55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_17a2860d925c3d306f1131cbc4cfe0f8 = $(`&lt;div id=&quot;html_17a2860d925c3d306f1131cbc4cfe0f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P5&lt;/div&gt;`)[0];
#             popup_9c547da0630076b55ed8e7a8b0abcb55.setContent(html_17a2860d925c3d306f1131cbc4cfe0f8);
#
#
#         marker_cfa7fd45e9cf63cc572ecbe54c5abfbc.bindPopup(popup_9c547da0630076b55ed8e7a8b0abcb55)
#         ;
#
#
#
#
#             var marker_18659c4080b308c068cd686f30335d0f = L.marker(
#                 [-12.0806133, -77.0418493],
#                 {}
#             ).addTo(map_a156d1790c59469b1775efc5efc5a853);
#
#
#         var popup_2a25b951fbab786a5e5c5bb459bb7ab3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2ea3f1196f7f14e9471d8b00d4fc20fa = $(`&lt;div id=&quot;html_2ea3f1196f7f14e9471d8b00d4fc20fa&quot; style=&quot;width: 100.0%; height:

# %%
zona=pd.read_excel("zonas.xlsx").copy()
mapa1=folium.Map(location = [-12.085,-77.04], tiles='OpenStreetMap', zoom_start = 15)

for x in list(zona.columns):
    zona1=zona.loc[zona[x].isna()==False]
    zona2=pd.DataFrame(zona1[x]).rename(columns={x:"npunto"})
    zona3=list(zona2.merge(data, how='left', on='npunto')["punto"])

    lat_point_list=[zona3[x][0] for x in range(len(zona3))]
    lon_point_list=[zona3[x][1] for x in range(len(zona3))]

    polygon_geom = Polygon(zip(lon_point_list, lat_point_list))
    crs = {'init': 'epsg:4326'}
    polygon = geopandas.GeoDataFrame(index=[0], crs=crs, geometry=[polygon_geom])       

    folium.GeoJson(polygon,style_function=(lambda x: {"color":"black","weight": 3.5,"fillOpacity":0})).add_to(mapa1)

delay=5
fn='testmap.html'
tmpurl='file://{path}/{mapfile}'.format(path=os.getcwd(),mapfile=fn)
mapa1.save(fn)

browser = webdriver.Chrome(ChromeDriverManager().install())
browser.get(tmpurl)

time.sleep(delay)
browser.save_screenshot('map.png')
browser.quit()

mapa1
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\user\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\user\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\user\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\user\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\user\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\user\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\user\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\user\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [C:\Users\user\.wdm\drivers\chromedriver\win32\103.0.5060.53\chromedriver.exe] found in cache
# C:\Users\user\AppData\Local\Temp/ipykernel_1956/3111208762.py:28: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(ChromeDriverManager().install())
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24f659d49cbcd1671450b1030c74737f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24f659d49cbcd1671450b1030c74737f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_24f659d49cbcd1671450b1030c74737f = L.map(
#                 &quot;map_24f659d49cbcd1671450b1030c74737f&quot;,
#                 {
#                     center: [-12.085, -77.04],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c96e2b197ad06efd0abd43f9ed34f4aa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24f659d49cbcd1671450b1030c74737f);
#
#
#         function geo_json_7258b3402ef2d252bda988cff279eb27_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 3.5};
#             }
#         }
#
#         function geo_json_7258b3402ef2d252bda988cff279eb27_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7258b3402ef2d252bda988cff279eb27 = L.geoJson(null, {
#                 onEachFeature: geo_json_7258b3402ef2d252bda988cff279eb27_onEachFeature,
#
#                 style: geo_json_7258b3402ef2d252bda988cff279eb27_styler,
#         });
#
#         function geo_json_7258b3402ef2d252bda988cff279eb27_add (data) {
#             geo_json_7258b3402ef2d252bda988cff279eb27
#                 .addData(data)
#                 .addTo(map_24f659d49cbcd1671450b1030c74737f);
#         }
#             geo_json_7258b3402ef2d252bda988cff279eb27_add({&quot;bbox&quot;: [-77.0487195, -12.0882483, -77.041113, -12.0829066], &quot;features&quot;: [{&quot;bbox&quot;: [-77.0487195, -12.0882483, -77.041113, -12.0829066], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-77.0481562, -12.0882483], [-77.0487195, -12.0852381], [-77.0461519, -12.0830168], [-77.0437315, -12.0831728], [-77.041976, -12.0829066], [-77.0418392, -12.0845098], [-77.0415891, -12.0844757], [-77.041113, -12.0877719], [-77.0425158, -12.0879446], [-77.0445311, -12.0877315], [-77.0481562, -12.0882483]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_57a3b5ccc751cdc16219fcf3c31a0fdc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 3.5};
#             }
#         }
#
#         function geo_json_57a3b5ccc751cdc16219fcf3c31a0fdc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_57a3b5ccc751cdc16219fcf3c31a0fdc = L.geoJson(null, {
#                 onEachFeature: geo_json_57a3b5ccc751cdc16219fcf3c31a0fdc_onEachFeature,
#
#                 style: geo_json_57a3b5ccc751cdc16219fcf3c31a0fdc_styler,
#         });
#
#         function geo_json_57a3b5ccc751cdc16219fcf3c31a0fdc_add (data) {
#             geo_json_57a3b5ccc751cdc16219fcf3c31a0fdc
#                 .addData(data)
#                 .addTo(map_24f659d49cbcd1671450b1030c74737f);
#         }
#             geo_json_57a3b5ccc751cdc16219fcf3c31a0fdc_add({&quot;bbox&quot;: [-77.041976, -12.0856323, -77.035583, -12.0798735], &quot;features&quot;: [{&quot;bbox&quot;: [-77.041976, -12.0856323, -77.035583, -12.0798735], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-77.041976, -12.0829066], [-77.0418493, -12.0806133], [-77.0363455, -12.0798735], [-77.035583, -12.0848357], [-77.0414714, -12.0856323], [-77.0415891, -12.0844757], [-77.0418392, -12.0845098], [-77.041976, -12.0829066]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_e76b4552427f69723abe72b0241e8bcc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 3.5};
#             }
#         }
#
#         function geo_json_e76b4552427f69723abe72b0241e8bcc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e76b4552427f69723abe72b0241e8bcc = L.geoJson(null, {
#                 onEachFeature: geo_json_e76b4552427f69723abe72b0241e8bcc_onEachFeature,
#
#                 style: geo_json_e76b4552427f69723abe72b0241e8bcc_styler,
#         });
#
#         function geo_json_e76b4552427f69723abe72b0241e8bcc_add (data) {
#             geo_json_e76b4552427f69723abe72b0241e8bcc
#                 .addData(data)
#                 .addTo(map_24f659d49cbcd1671450b1030c74737f);
#         }

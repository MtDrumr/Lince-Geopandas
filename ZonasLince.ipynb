# %%
import pandas as pd
import numpy as np
import geopandas
import folium
from folium import plugins
from shapely.geometry import Polygon

# %%
list1=[
(-12.0882483,-77.0481562),
(-12.0852381,-77.0487195),
(-12.0830168,-77.0461519),
(-12.0831728,-77.0437315),
(-12.0829066,-77.0419760),
(-12.0806133,-77.0418493),
(-12.0798735,-77.0363455),
(-12.0795248,-77.0340598),
(-12.0787554,-77.0283873),
(-12.0855543,-77.0256259),
(-12.0907578,-77.0236173),
(-12.0873794,-77.0385976),
(-12.0877719,-77.0411130),
(-12.0879446,-77.0425158),
(-12.0844757,-77.0415891),
(-12.0845098,-77.0418392),
(-12.0856323,-77.0414714),
(-12.0848357,-77.0355830),
(-12.0845169,-77.0333614),
(-12.0858572,-77.0354572),
(-12.0855445,-77.0332062),
(-12.0837365,-77.0280918),
(-12.0859330,-77.0284258),
(-12.0918362,-77.0301183),
(-12.0911476,-77.0299399),
(-12.0908824,-77.0324193),
(-12.0906723,-77.0336545),
(-12.0887150,-77.0350658),
(-12.0885767,-77.0340092),
(-12.0893074,-77.0349726),
(-12.0897287,-77.0382360),
(-12.0904565,-77.0432078),
(-12.0912263,-77.0431237),
(-12.0916951,-77.0464979),
(-12.0913771,-77.0465549),
(-12.0915729,-77.0476520),
(-12.0877315,-77.0445311),
(-12.0891458,-77.0339136)
]

list2=[]

mapa1=folium.Map(location = [-12.085,-77.04], tiles='OpenStreetMap', zoom_start = 15)

for x in range(len(list1)):
    npunto="P{}".format(x+1)
    list2.append(npunto)
    mapa1.add_child(folium.Marker(location = list1[x],popup = npunto))
    
data=pd.DataFrame(data={"npunto":list2,"punto":list1})

mapa1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8b7a2aed53e8ff4f4f02ff85327e640 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8b7a2aed53e8ff4f4f02ff85327e640&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a8b7a2aed53e8ff4f4f02ff85327e640 = L.map(
#                 &quot;map_a8b7a2aed53e8ff4f4f02ff85327e640&quot;,
#                 {
#                     center: [-12.085, -77.04],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d42b8df9df0e0110f039be2d58024af2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a8b7a2aed53e8ff4f4f02ff85327e640);
#
#
#             var marker_dcdd75167e1419ff1f0bfdcf8fd9a698 = L.marker(
#                 [-12.0882483, -77.0481562],
#                 {}
#             ).addTo(map_a8b7a2aed53e8ff4f4f02ff85327e640);
#
#
#         var popup_9eb9c3ab42150aeec663fcef60027dbe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_28feb6a3bb01b08040960cf8f16f33fc = $(`&lt;div id=&quot;html_28feb6a3bb01b08040960cf8f16f33fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P1&lt;/div&gt;`)[0];
#             popup_9eb9c3ab42150aeec663fcef60027dbe.setContent(html_28feb6a3bb01b08040960cf8f16f33fc);
#
#
#         marker_dcdd75167e1419ff1f0bfdcf8fd9a698.bindPopup(popup_9eb9c3ab42150aeec663fcef60027dbe)
#         ;
#
#
#
#
#             var marker_2b664a80edc4ac13b6a9f8c7b49b026e = L.marker(
#                 [-12.0852381, -77.0487195],
#                 {}
#             ).addTo(map_a8b7a2aed53e8ff4f4f02ff85327e640);
#
#
#         var popup_1fc7f6de5dcd279bcbfe438322e6289f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_164149fbda249b3546576c2b5d1936db = $(`&lt;div id=&quot;html_164149fbda249b3546576c2b5d1936db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P2&lt;/div&gt;`)[0];
#             popup_1fc7f6de5dcd279bcbfe438322e6289f.setContent(html_164149fbda249b3546576c2b5d1936db);
#
#
#         marker_2b664a80edc4ac13b6a9f8c7b49b026e.bindPopup(popup_1fc7f6de5dcd279bcbfe438322e6289f)
#         ;
#
#
#
#
#             var marker_95aff702d8f2081d8ebc4a805d28e151 = L.marker(
#                 [-12.0830168, -77.0461519],
#                 {}
#             ).addTo(map_a8b7a2aed53e8ff4f4f02ff85327e640);
#
#
#         var popup_8c868ee4dd3f93505463af41616a2dfc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8356222c0ede93606c4a9a719c80f32b = $(`&lt;div id=&quot;html_8356222c0ede93606c4a9a719c80f32b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P3&lt;/div&gt;`)[0];
#             popup_8c868ee4dd3f93505463af41616a2dfc.setContent(html_8356222c0ede93606c4a9a719c80f32b);
#
#
#         marker_95aff702d8f2081d8ebc4a805d28e151.bindPopup(popup_8c868ee4dd3f93505463af41616a2dfc)
#         ;
#
#
#
#
#             var marker_65356dee29800c05aa7651a73f292c44 = L.marker(
#                 [-12.0831728, -77.0437315],
#                 {}
#             ).addTo(map_a8b7a2aed53e8ff4f4f02ff85327e640);
#
#
#         var popup_09338bb93b2e062e0e53328359f508d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7960cb0359bf950921a96c1fe5b1d944 = $(`&lt;div id=&quot;html_7960cb0359bf950921a96c1fe5b1d944&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P4&lt;/div&gt;`)[0];
#             popup_09338bb93b2e062e0e53328359f508d3.setContent(html_7960cb0359bf950921a96c1fe5b1d944);
#
#
#         marker_65356dee29800c05aa7651a73f292c44.bindPopup(popup_09338bb93b2e062e0e53328359f508d3)
#         ;
#
#
#
#
#             var marker_f6e5123a8a5438d2c2d4c678a85d1a98 = L.marker(
#                 [-12.0829066, -77.041976],
#                 {}
#             ).addTo(map_a8b7a2aed53e8ff4f4f02ff85327e640);
#
#
#         var popup_f91ffe68b44ca04d260d83a251f8d41c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b2696a7f847a740171dcba272e110691 = $(`&lt;div id=&quot;html_b2696a7f847a740171dcba272e110691&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P5&lt;/div&gt;`)[0];
#             popup_f91ffe68b44ca04d260d83a251f8d41c.setContent(html_b2696a7f847a740171dcba272e110691);
#
#
#         marker_f6e5123a8a5438d2c2d4c678a85d1a98.bindPopup(popup_f91ffe68b44ca04d260d83a251f8d41c)
#         ;
#
#
#
#
#             var marker_89d4d8c3dbb02c53748bfe14c2e9cfad = L.marker(
#                 [-12.0806133, -77.0418493],
#                 {}
#             ).addTo(map_a8b7a2aed53e8ff4f4f02ff85327e640);
#
#
#         var popup_93b6d5915082244c7ddd41d1e40f03d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6922e87de2e3abca1b4a3af7a0fc6d09 = $(`&lt;div id=&quot;html_6922e87de2e3abca1b4a3af7a0fc6d09&quot; style=&quot;width: 100.0%; height:

# %%
zona_0=[]
zona_1=['P1', 'P2', 'P3', 'P4', 'P5', 'P16', 'P15', 'P13', 'P14', 'P37', np.nan]
zona_2=['P5', 'P6', 'P7', 'P18', 'P17', 'P15', 'P16', np.nan, np.nan, np.nan, np.nan]
zona_3=['P7', 'P8', 'P21', 'P20', np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]
zona_4=['P8', 'P9', 'P10', 'P23', 'P22', 'P19', np.nan, np.nan, np.nan, np.nan, np.nan]
zona_5=['P10', 'P11', 'P24', 'P23', np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]
zona_6=['P22', 'P23', 'P25', 'P26', 'P19', np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]
zona_7=['P21', 'P26', 'P27', 'P38', 'P30', 'P20', np.nan, np.nan, np.nan, np.nan, np.nan]
zona_8=['P17', 'P18', 'P30', 'P31', 'P12', 'P13', np.nan, np.nan, np.nan, np.nan, np.nan]
zona_9=['P1', 'P37', 'P14', 'P13', 'P12', 'P31', 'P32', 'P33', 'P34', 'P35', 'P36']

zona_0.append(zona_1)
zona_0.append(zona_2)
zona_0.append(zona_3)
zona_0.append(zona_4)
zona_0.append(zona_5)
zona_0.append(zona_6)
zona_0.append(zona_7)
zona_0.append(zona_8)
zona_0.append(zona_9)
zona_0

data0={
    "zona1":[],
    "zona2":[],
    "zona3":[],
    "zona4":[],
    "zona5":[],
    "zona6":[],
    "zona7":[],
    "zona8":[],
    "zona9":[],
}

var1=0
for x in data0.keys():
    for i in zona_0[var1]:
        data0[x].append(i)
    var1+=1
    
zona0=pd.DataFrame(data=data0)

# %%
lista_zonas1=[]
lista_zonas2=[]
lista_var=1

for x in list(zona0.columns):
    zona1=zona0.loc[zona0[x].isna()==False]
    zona2=pd.DataFrame(zona1[x]).rename(columns={x:"npunto"})
    zona3=list(zona2.merge(data, how='left', on='npunto')["punto"])

    lat_point_list=[zona3[x][0] for x in range(len(zona3))]
    lon_point_list=[zona3[x][1] for x in range(len(zona3))]

    polygon_geom = Polygon(zip(lon_point_list, lat_point_list))
    crs = {'init': 'epsg:4326'}
    polygon = geopandas.GeoDataFrame(index=[0], crs=crs, geometry=[polygon_geom])     
    lista_zonas1.append("Zona {}".format(lista_var))
    lista_zonas2.append(polygon)
    lista_var+=1
    

lince5=pd.DataFrame(data={"ZONA1":lista_zonas1,"geometry":lista_zonas2}).copy()
lince5
# Out:
#     ZONA1                                           geometry
# 0  Zona 1                                              ge...
# 1  Zona 2                                              ge...
# 2  Zona 3                                              ge...
# 3  Zona 4                                              ge...
# 4  Zona 5                                              ge...
# 5  Zona 6                                              ge...
# 6  Zona 7                                              ge...
# 7  Zona 8                                              ge...
# 8  Zona 9                                              ge...

# %%
mapa1=folium.Map(location = [-12.085,-77.04], tiles='OpenStreetMap', zoom_start = 15)

for x in range(lince5.shape[0]):
    geo_j = folium.GeoJson(lince5["geometry"][x]["geometry"][0],
        style_function=lambda x: {"color":"black","weight": 3.5,"fillOpacity":0})
    folium.Popup(lince5["ZONA1"][x]).add_to(geo_j)
    geo_j.add_to(mapa1)

mapa1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8449b0d86038cfed208950e6a3565fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8449b0d86038cfed208950e6a3565fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d8449b0d86038cfed208950e6a3565fa = L.map(
#                 &quot;map_d8449b0d86038cfed208950e6a3565fa&quot;,
#                 {
#                     center: [-12.085, -77.04],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85beb6a2309d2405b9aed3c3401caff4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8449b0d86038cfed208950e6a3565fa);
#
#
#         function geo_json_261f4819795b8c1feeb53d01c9a354bd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 3.5};
#             }
#         }
#
#         function geo_json_261f4819795b8c1feeb53d01c9a354bd_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_261f4819795b8c1feeb53d01c9a354bd = L.geoJson(null, {
#                 onEachFeature: geo_json_261f4819795b8c1feeb53d01c9a354bd_onEachFeature,
#
#                 style: geo_json_261f4819795b8c1feeb53d01c9a354bd_styler,
#         });
#
#         function geo_json_261f4819795b8c1feeb53d01c9a354bd_add (data) {
#             geo_json_261f4819795b8c1feeb53d01c9a354bd
#                 .addData(data)
#                 .addTo(map_d8449b0d86038cfed208950e6a3565fa);
#         }
#             geo_json_261f4819795b8c1feeb53d01c9a354bd_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-77.0481562, -12.0882483], [-77.0487195, -12.0852381], [-77.0461519, -12.0830168], [-77.0437315, -12.0831728], [-77.041976, -12.0829066], [-77.0418392, -12.0845098], [-77.0415891, -12.0844757], [-77.041113, -12.0877719], [-77.0425158, -12.0879446], [-77.0445311, -12.0877315], [-77.0481562, -12.0882483]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_226419003a9bc8e6cf1b5d2e8636dd81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d89c3b2470fccd74d3b56548b518c749 = $(`&lt;div id=&quot;html_d89c3b2470fccd74d3b56548b518c749&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zona 1&lt;/div&gt;`)[0];
#             popup_226419003a9bc8e6cf1b5d2e8636dd81.setContent(html_d89c3b2470fccd74d3b56548b518c749);
#
#
#         geo_json_261f4819795b8c1feeb53d01c9a354bd.bindPopup(popup_226419003a9bc8e6cf1b5d2e8636dd81)
#         ;
#
#
#
#
#         function geo_json_2f7684bcc3e9342ac2f32a7d026a4578_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 3.5};
#             }
#         }
#
#         function geo_json_2f7684bcc3e9342ac2f32a7d026a4578_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2f7684bcc3e9342ac2f32a7d026a4578 = L.geoJson(null, {
#                 onEachFeature: geo_json_2f7684bcc3e9342ac2f32a7d026a4578_onEachFeature,
#
#                 style: geo_json_2f7684bcc3e9342ac2f32a7d026a4578_styler,
#         });
#
#         function geo_json_2f7684bcc3e9342ac2f32a7d026a4578_add (data) {
#             geo_json_2f7684bcc3e9342ac2f32a7d026a4578
#                 .addData(data)
#                 .addTo(map_d8449b0d86038cfed208950e6a3565fa);
#         }
#             geo_json_2f7684bcc3e9342ac2f32a7d026a4578_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-77.041976, -12.0829066], [-77.0418493, -12.0806133], [-77.0363455, -12.0798735], [-77.035583, -12.0848357], [-77.0414714, -12.0856323], [-77.0415891, -12.0844757], [-77.0418392, -12.0845098], [-77.041976, -12.0829066]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_c5b40e8b42a1e67aad0ea154a746e87c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_61d2f213c6d9a89b1bc1f5fd76c38cd1 = $(`&lt;div id=&quot;html_61d2f213c6d9a89b1bc1f5fd76c38cd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zona 2&lt;/div&gt;`)[0];
#             popup_c5b40e8b42a1e67aad0ea154a746e87c.setContent(html_61d2f213c6d9a89b1bc1f5fd76c38cd1);
#
#
#         geo_json_2f7684bcc3e9342ac2f32a7d026a4578.bindPopup(popup_c5b40e8b42a1e67aad0ea154a746e87c)
#         ;
#
#
#
#
#         function geo_json_41fd89a543b3916f158c308868613fd9_styler(feature) {
#             switch(feature.id) {
#                 default:
